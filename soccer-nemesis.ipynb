# %%
import pandas as pd
import matplotlib.pylab as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# ## read the dataset

# %%
df_results = pd.read_csv('./data/results_per_team_and_opponent.csv')
df_aggregated = pd.read_csv('./data/aggregated_result_per_team_and_opponent.csv')

# %% [markdown]
# ## Get the worst performing opponent for each team

# %%
team = 'Valencia CF'
temp = df_aggregated[ (df_aggregated['total_num_games']>300) & (df_aggregated['team']==team) & (df_aggregated['num_games']>10)].sort_values(by='result_metric')
temp.loc[temp['result_metric'].argmin(),'opponent']
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   app.launch_new_instance()
# 'Real Sociedad'

# %%
df_aggregated.head()
# Out:
#                    team  total_num_games  num_games             opponent  \
# 0  1. FC Kaiserslautern             68.0        4.0           1. FC Köln
# 1  1. FC Kaiserslautern             68.0        4.0       1. FC Nürnberg
# 2  1. FC Kaiserslautern             68.0        4.0      1. FSV Mainz 05
# 3  1. FC Kaiserslautern             68.0        4.0  Bayer 04 Leverkusen
# 4  1. FC Kaiserslautern             68.0        4.0    Borussia Dortmund
#
#    pct_of_points  result_metric
# 0      41.666667            5.0
# 1      25.000000            3.0
# 2      25.000000            3.0
# 3       0.000000            0.0
# 4      16.666667            2.0

# %%
df_nemesis = pd.DataFrame(columns = ['team','nemesis', 'worst_result', 'num_games'])

## here i filter only for teams that have at least 300 games in the dataset. 
## if you want to find a team that played fewer games, simply reduce the 300 number to a lower number.
for team in df_aggregated[df_aggregated['total_num_games']>270]['team'].unique():
    temp = df_aggregated[ (df_aggregated['total_num_games']>270) & (df_aggregated['team']==team) & (df_aggregated['num_games']>10)].sort_values(by='result_metric')
    nemesis = temp.loc[temp['pct_of_points'].argmin(), 'opponent']
    num_games = temp.loc[temp['pct_of_points'].argmin(), 'num_games']
    df_nemesis.loc[len(df_nemesis)] = [team, nemesis, temp['pct_of_points'].min() , num_games]
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:8: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.

# %%
df_nemesis['worst_result'] = round(df_nemesis['worst_result'],2)

# %%
df_nemesis.rename(columns={'worst_result':'pct_points'}, inplace=True)

# %%
df_nemesis.sort_values(by='pct_points', ascending=False)
# Out:
#                         team                   nemesis  pct_points  num_games
# 11              FC Barcelona             Real Sociedad       52.78       12.0
# 12          FC Bayern Munich  Borussia Mönchengladbach       50.00       16.0
# 22                  Juventus                    Napoli       46.67       15.0
# 30                    Napoli                      Roma       39.58       16.0
# 6          Borussia Dortmund          FC Bayern Munich       39.58       16.0
# 8                    Chelsea                 Liverpool       39.58       16.0
# 26           Manchester City                 Liverpool       37.50       16.0
# 18     Girondins de Bordeaux    Olympique de Marseille       37.50       16.0
# 27         Manchester United                   Chelsea       37.50       16.0
# 33    Olympique de Marseille        Olympique Lyonnais       31.25       16.0
# 7   Borussia Mönchengladbach         Borussia Dortmund       31.25       16.0
# 32        Olympique Lyonnais       Paris Saint-Germain       31.25       16.0
# 28                     Milan                  Juventus       29.17       16.0
# 21                     Inter                  Juventus       29.17       16.0
# 25                 Liverpool                   Arsenal       29.17       16.0
# 36            Real Madrid CF              FC Barcelona       29.17       16.0
# 44         Tottenham Hotspur         Manchester United       29.17       16.0
# 5        Bayer 04 Leverkusen         Borussia Dortmund       29.17       16.0
# 46                   Udinese                  Juventus       29.17       16.0
# 31                  OGC Nice    Montpellier Hérault SC       28.57       14.0
# 34       Paris Saint-Germain                 AS Monaco       27.78       12.0
# 40          Stade Rennais FC     Girondins de Bordeaux       27.08       16.0
# 23                LOSC Lille       Paris Saint-Germain       27.08       16.0
# 1                    Arsenal                   Chelsea       25.00       16.0
# 37                      Roma                  Juventus       25.00       16.0
# 47               Valencia CF              FC Barcelona       22.92       16.0
# 45               Toulouse FC       Paris Saint-Germain       20.83       16.0
# 0           AS Saint-Étienne    Olympique de Marseille       20.83       16.0
# 19              Hamburger SV          FC Bayern Munich       20.83       16.0
# 13                FC Lorient       Paris Saint-Germain       20.83       16.0
# 16                     Genoa                  Juventus       20.00       15.0
# 20               Hannover 96          FC Bayern Munich       18.75       16.0
# 15                Fiorentina                  Juventus       18.75       16.0
# 14             FC Schalke 04          FC Bayern Munich       18.75       16.0
# 42                Sunderland         Manchester United       18.75       16.0
# 10                   Everton                   Arsenal       18.75       16.0
# 41                Stoke City         Manchester United       16.67       16.0
# 4            Atlético Madrid              FC Barcelona       16.67       16.0
# 49             VfL Wolfsburg          FC Bayern Munich       14.58       16.0
# 2                Aston Villa         Manchester United       14.58       16.0
# 3    Athletic Club de Bilbao              FC Barcelona       12.50       16.0
# 39                Sevilla FC              FC Barcelona       12.50       16.0
# 38          SV Werder Bremen          FC Bayern Munich       12.50       16.0
# 17                 Getafe CF              FC Barcelona       12.50       16.0
# 48             VfB Stuttgart          FC Bayern Munich       10.42       16.0
# 29                 Málaga CF              FC Barcelona        8.33       16.0
# 43       TSG 1899 Hoffenheim          FC Bayern Munich        8.33       16.0
# 24                     Lazio                  Juventus        8.33       16.0
# 9              Chievo Verona                     Milan        6.25       16.0
# 35              RCD Espanyol            Real Madrid CF        6.25       16.0

# %%
team = 'FC Barcelona'

temp = df_aggregated[ (df_aggregated['total_num_games']>300) &\
                     (df_aggregated['team']==team) & (df_aggregated['num_games']>10)].sort_values(by='result_metric')
temp.sort_values(by = 'pct_of_points')
# Out:
#               team  total_num_games  num_games                   opponent  \
# 1287  FC Barcelona            304.0       12.0              Real Sociedad
# 1286  FC Barcelona            304.0       16.0             Real Madrid CF
# 1295  FC Barcelona            304.0       16.0                Valencia CF
# 1268  FC Barcelona            304.0       12.0                 CA Osasuna
# 1279  FC Barcelona            304.0       12.0  RC Deportivo de La Coruña
# 1267  FC Barcelona            304.0       16.0            Atlético Madrid
# 1296  FC Barcelona            304.0       14.0              Villarreal CF
# 1266  FC Barcelona            304.0       16.0    Athletic Club de Bilbao
# 1273  FC Barcelona            304.0       16.0                  Getafe CF
# 1281  FC Barcelona            304.0       16.0               RCD Espanyol
# 1292  FC Barcelona            304.0       16.0                 Sevilla FC
# 1276  FC Barcelona            304.0       12.0                 Levante UD
# 1277  FC Barcelona            304.0       16.0                  Málaga CF
#
#       pct_of_points  result_metric
# 1287      52.777778           19.0
# 1286      66.666667           32.0
# 1295      66.666667           32.0
# 1268      72.222222           26.0
# 1279      77.777778           28.0
# 1267      79.166667           38.0
# 1296      80.952381           34.0
# 1266      81.250000           39.0
# 1273      81.250000           39.0
# 1281      81.250000           39.0
# 1292      81.250000           39.0
# 1276      88.888889           32.0
# 1277      89.583333           43.0
